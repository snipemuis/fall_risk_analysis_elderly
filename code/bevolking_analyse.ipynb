# %%
import sys
import pandas as pd
sys.path.insert(0, '.')

from risico_analyse_valincidenten import RisicoAnalyseValincidenten

analyse = RisicoAnalyseValincidenten()
data = analyse.data

data.to_csv('../data/risico_analyse_valincidenten.csv', index=False)
